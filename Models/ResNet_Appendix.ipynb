# %% [markdown]
# Here are the ResNet models I ran but had low accuracy and/or overfitting.

# %%
#For Google Collab
from google.colab import drive, auth
from googleapiclient.discovery import build
#For data manipulation
import numpy as np 
import pandas as pd 
import random
#For Plotting
import matplotlib.pyplot as plt
#For Modeling
import keras
from sklearn.model_selection import train_test_split
from keras.models import Model
from keras.layers import Conv2D, Dense, Flatten, Dropout, MaxPooling2D, BatchNormalization, Input, concatenate
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ReduceLROnPlateau
from keras import optimizers, regularizers
from keras.optimizers import Adam, SGD
from keras.applications.resnet50 import ResNet50
from keras.callbacks  import ModelCheckpoint, LearningRateScheduler, EarlyStopping, ReduceLROnPlateau

# %%
# Load the Drive helper and mount
# This will prompt for authorization.
drive.mount('/content/drive')

# %%
auth.authenticate_user()

# %%
drive_service = build('drive', 'v3')

# %%
#Create variable for image and batch size along with number of epochs committing to for model
height = 224
width = 224
batch_size = 32

train = ImageDataGenerator(rescale = 1/.255,rotation_range=30,horizontal_flip=True)
test = ImageDataGenerator(rescale=1/.255,rotation_range=30,horizontal_flip=True)

# %%
#Seting up train, test, and val sets for model

train_set = train.flow_from_directory('../content/drive/My Drive/Chest_X_rays/All_Chest/train'
                                      ,target_size=(width,height), 
                                      batch_size=batch_size,
                                      shuffle = True,
                                      class_mode='categorical',
                                     seed = 122)
test_set = train.flow_from_directory('../content/drive/My Drive/Chest_X_rays/All_Chest/test'
                                      ,target_size=(width,height), 
                                      batch_size=batch_size,
                                     shuffle = True,
                                      class_mode='categorical',                               
                                    seed = 122)
val_set = train.flow_from_directory('../content/drive/My Drive/Chest_X_rays/All_Chest/val'
                                      ,target_size=(width,height), 
                                      batch_size=batch_size,
                                    shuffle = True,
                                      class_mode='categorical',                                  
                                    seed = 122)

# %%
def model():
    image_input = Input(shape=(224,224, 3))
    model=ResNet50(weights='imagenet',include_top=True, input_tensor=image_input)
    last_layer = model.get_layer('fc1000').output
    out = Dense(1000, activation='relu', name='fc10006')(last_layer)
    out = Dense(500, activation='relu', name='fc10005')(last_layer)
    out = Dense(400, activation='relu',name ='fc1004')(out)
    #out = Dense(300, activation='relu',name ='fc1003')(out)
    out = Dense(200, activation='relu',name ='fc1002')(out)
    out = Dense(100, activation='relu',name ='fc1001')(out)
    out = Dense(3, activation='softmax',name ='fc1006')(out)
    custom_model = Model(input=image_input,output=out)

    
    return custom_model
  
model_Res = model()

# %%
rt=ReduceLROnPlateau(monitor='val_acc', factor=0.1, patience=1, verbose=1, mode='auto', min_delta=0.01, cooldown=1, min_lr=.0000009)
es = EarlyStopping(monitor='val_acc', min_delta=.05, patience=2, verbose=1, mode='auto', baseline=None, restore_best_weights=False)
model_Res.compile(loss=keras.losses.categorical_crossentropy,
                 optimizer=SGD(lr=0.0005, nesterov = True),
                 metrics=['accuracy'])
history = model_Res.fit_generator(train_set, steps_per_epoch=1, epochs=10, validation_steps=1, verbose=1, validation_data=test_set,callbacks=[rt])
history

# %%
plt.plot(history.history['loss'], label = 'Train')
plt.plot(history.history['val_loss'], label = 'Test')
plt.legend(loc = 'upper right')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.title('Loss')
plt.show()

plt.plot(history.history['acc'], label = 'Train')
plt.plot(history.history['val_acc'], label = 'Test')
plt.legend(loc = 'upper right')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.title('Accuracy')
plt.show()

# %%
def model():
    image_input = Input(shape=(224,224, 3))
    model=ResNet50(weights='imagenet',include_top=True, input_tensor=image_input)
    last_layer = model.get_layer('fc1000').output
    out = Dense(1028, activation='relu', name='fc10006')(last_layer)
    out = Dense(512, activation='relu', name='fc10005')(last_layer)
    out = Dense(256, activation='relu',name ='fc1004')(out)
    out = Dense(128, activation='relu',name ='fc1003')(out)
    out = Dense(64, activation='relu',name ='fc1002')(out)
    out = Dense(32, activation='relu',name ='fc1001')(out)
    out = Dense(3, activation='softmax',name ='fc1006')(out)
    custom_model = Model(input=image_input,output=out)

    
    return custom_model
  
model_Res = model()

# %%
rt=ReduceLROnPlateau(monitor='val_acc', factor=0.1, patience=1, verbose=1, mode='auto', min_delta=0.01, cooldown=1, min_lr=.00000001)
es = EarlyStopping(monitor='val_loss', min_delta=.05, patience=2, verbose=1, mode='auto', baseline=None, restore_best_weights=False)
model_Res.compile(loss=keras.losses.categorical_crossentropy,
                 optimizer=SGD(lr=0.001, nesterov = True),
                 metrics=['accuracy'])
history = model_Res.fit_generator(train_set, steps_per_epoch=15, epochs=10, validation_steps=15, verbose=1, validation_data=test_set,callbacks=[rt])
history

# %%
plt.plot(history.history['loss'], label = 'Train')
plt.plot(history.history['val_loss'], label = 'Test')
plt.legend(loc = 'upper right')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.title('Loss')
plt.show()

plt.plot(history.history['acc'], label = 'Train')
plt.plot(history.history['val_acc'], label = 'Test')
plt.legend(loc = 'upper right')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.title('Accuracy')
plt.show()

# %%
rt=ReduceLROnPlateau(monitor='val_acc', factor=0.1, patience=1, verbose=1, mode='auto', min_delta=0.01, cooldown=1, min_lr=.0000000000000000000000000000000000000001)
es = EarlyStopping(monitor='val_acc', min_delta=.05, patience=2, verbose=1, mode='auto', baseline=None, restore_best_weights=False)
model_Res.compile(loss=keras.losses.categorical_crossentropy,
                 optimizer=SGD(lr=0.000000005, nesterov = True),
                 metrics=['accuracy'])
history = model_Res.fit_generator(train_set, steps_per_epoch=10, epochs=10, validation_steps=10, verbose=1, validation_data=test_set,callbacks=[rt])
history

# %%
plt.plot(history.history['loss'], label = 'Train')
plt.plot(history.history['val_loss'], label = 'Test')
plt.legend(loc = 'upper right')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.title('Loss')
plt.show()

plt.plot(history.history['acc'], label = 'Train')
plt.plot(history.history['val_acc'], label = 'Test')
plt.legend(loc = 'upper right')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.title('Accuracy')
plt.show()
